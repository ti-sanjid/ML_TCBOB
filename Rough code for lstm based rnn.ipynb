# %%
import numpy as np

# %%
import pandas as pd
import numpy as np

# Generate random data
np.random.seed(0)
x = np.random.randn(100, 5)  # 100 rows, 5 columns

# Convert to DataFrame
df = pd.DataFrame(x, columns=['Feature1', 'Feature2', 'Feature3', 'Feature4', 'Feature5'])

# Display the DataFrame
df
# Out:
#     Feature1  Feature2  Feature3  Feature4  Feature5
# 0   1.764052  0.400157  0.978738  2.240893  1.867558
# 1  -0.977278  0.950088 -0.151357 -0.103219  0.410599
# 2   0.144044  1.454274  0.761038  0.121675  0.443863
# 3   0.333674  1.494079 -0.205158  0.313068 -0.854096
# 4  -2.552990  0.653619  0.864436 -0.742165  2.269755
# ..       ...       ...       ...       ...       ...
# 95  0.994394  1.319137 -0.882419  1.128594  0.496001
# 96  0.771406  1.029439 -0.908763 -0.424318  0.862596
# 97 -2.655619  1.513328  0.553132 -0.045704  0.220508
# 98 -1.029935 -0.349943  1.100284  1.298022  2.696224
# 99 -0.073925 -0.658553 -0.514234 -1.018042 -0.077855
#
# [100 rows x 5 columns]

# %%
import numpy as np
import tensorflow as tf

# Generate random data
np.random.seed(0)
X = np.random.randn(100, 5)  # 100 time steps, 5 features per step
Y = np.sin(np.arange(100) / 10.0)  # Target variable (sine wave for demonstration)

# X.shape[1]
# Y

# Reshape data for LSTM
X = X.reshape(X.shape[0], X.shape[1], 1)

# Define the LSTM-based RNN model
def build_lstm_rnn(input_shape):
    model = tf.keras.Sequential([
        tf.keras.layers.LSTM(64, return_sequences=True, input_shape=input_shape),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.LSTM(64),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(1)  # For regression tasks
    ])
    return model

# Define input shape
input_shape = (5, 1)  # 5 features, 1 channel

# Create the LSTM RNN model
model = build_lstm_rnn(input_shape)

# Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Train the model
model.fit(X, Y, epochs=10, batch_size=32, verbose=1)
# Out:
# 5

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Generate random data and convert to DataFrame
np.random.seed(0)
x = np.random.randn(100, 5)
df = pd.DataFrame(x, columns=['Feature1', 'Feature2', 'Feature3', 'Feature4', 'Feature5'])

# Define the number of time steps (sequence length)
n_steps = 3  # You can adjust this based on your specific use case

# Create sequences of data
# Create sequences of data
# Create sequences of data
sequences = []
for i in range(len(df) - n_steps + 1):
    seq = df.iloc[i:i+n_steps].values
    sequences.append(seq)



# Convert sequences to NumPy array
sequences = np.array(sequences)

# Separate input (X) and output (y)
X = sequences[:, :-1]
y = sequences[:, -1]

# Define the LSTM model
model = Sequential([
    LSTM(64, activation='relu', input_shape=(n_steps, df.shape[1])),
    Dense(df.shape[1])  # Output layer with the same number of features as input
])

# Compile the model
model.compile(optimizer='adam', loss='mse')  # Adjust loss function as needed

# Train the model
model.fit(X, y, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 41
#      38 model.compile(optimizer='adam', loss='mse')  # Adjust loss function as needed
#      40 # Train the model
# ---> 41 model.fit(X, y, epochs=10, batch_size=32)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /tmp/__autograph_generated_filexe8emedx.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ...
