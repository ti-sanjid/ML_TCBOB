# %%
# !pip install numpy==1.20.3

# %%
# !apt-get install -qq libgdal-dev libproj-dev
# #!pip install --no-binary shapely shapely
# !pip install --no-binary shapely shapely --force
# !pip install cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import tensorflow as tf
from tensorflow import keras
import warnings
import numpy as np
warnings.filterwarnings("ignore")

print(tf.__version__)
# Out:
# 2.12.0

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/mnt/1A42C1DD42C1BE2F/MyProjects/ML_TCBOB/Data/Preprocessed data/rearranged_final[date_ 3rd august 2023].csv")

# %%
df
# Out:
#       NUMBER             ISO_TIME    lat    lon  q_eye_150  q_eye_500  \
# 0          1  1978-11-19 00:00:00   6.75  90.75   0.000011   0.004364
# 1          1  1978-11-19 03:00:00   7.00  90.50   0.000011   0.005096
# 2          1  1978-11-19 06:00:00   7.00  90.50   0.000012   0.005281
# 3          1  1978-11-19 09:00:00   7.50  90.25   0.000012   0.005514
# 4          1  1978-11-19 12:00:00   7.50  90.00   0.000011   0.005361
# ...      ...                  ...    ...    ...        ...        ...
# 1824      58  2021-12-04 18:00:00  17.00  84.25   0.000016   0.002354
# 1825      58  2021-12-04 21:00:00  17.25  84.50   0.000015   0.002231
# 1826      58  2021-12-05 00:00:00  18.00  84.50   0.000014   0.001984
# 1827      58  2021-12-05 03:00:00  18.25  84.50   0.000014   0.000942
# 1828      58  2021-12-05 06:00:00  18.50  84.50   0.000015   0.001061
#
#       q_eye_850   r_eye_150   r_eye_500   r_eye_550  ...  T-12_93_18_sst  \
# 0      0.000011   99.773224   87.319725   99.773224  ...      300.817596
# 1      0.000011   97.561157  100.889244   97.561157  ...      300.817596
# 2      0.000012   97.990585   99.541031   97.990585  ...      300.817596
# 3      0.000012   98.904373  100.814346   98.904373  ...      300.817596
# 4      0.000011   98.951813   97.860756   98.951813  ...      300.627380
# ...         ...         ...         ...         ...  ...             ...
# 1824   0.000016  100.889832   40.162926  100.889832  ...      302.722717
# 1825   0.000015   98.258652   36.168449   98.258652  ...      302.722717
# 1826   0.000014   90.667793   30.521656   90.667793  ...      302.722717
# 1827   0.000014   93.255341   17.373974   93.255341  ...      302.722717
# 1828   0.000015   91.804787   16.828655   91.804787  ...      302.722717
#
#       T-12_96_0_sst  T-12_96_6_sst  T-12_96_9_sst  T-12_96_12_sst  \
# 0        302.189789     301.535431     301.185730      301.064728
# 1        302.189789     301.535431     301.185730      301.064728
# 2        302.189789     301.535431     301.185730      301.064728
# 3        302.189789     301.535431     301.185730      301.064728
# 4        302.158661     301.436127     301.069824      300.942902
# ...             ...            ...            ...             ...
# 1824     302.218842     302.130829     301.951263      301.852570
# 1825     302.218842     302.130829     301.951263      301.852570
# 1826     302.218842     302.130829     301.951263      301.852570
# 1827     302.218842     302.130829     301.951263      301.852570
# 1828     302.218842     302.130829     301.951263      301.852570
#
#       T-12_96_15_sst  T-12_99_0_sst  T-12_99_6_sst  Lat +6  Lon +6
# 0         300.869385     302.642883     301.879181    7.00   90.50
# 1         300.869385     302.642883     301.879181    7.50   90.25
# 2         300.869385     302.642883     301.879181    7.50   90.00
# 3         300.869385     302.642883     301.879181    7.50   90.25
# 4         300.720123     302.554230     301.892090    7.75   89.75
# ...              ...            ...            ...     ...     ...
# 1824      302.243225     302.636749     302.461884   18.00   84.50
# 1825      302.243225     302.636749     302.461884   18.25   84.50
# 1826      302.243225     302.636749     302.461884   18.50   84.50
# 1827      302.243225     302.636749     302.461884     NaN     NaN
# 1828      302.243225     302.636749     302.461884     NaN     NaN
#
# [1829 rows x 1444 columns]

# %%
# df2 = df.fillna(method="ffill")

# %%
# df2.insert(loc = 0,
#           column = 'index',
#           value = df.index)

# %%
# year = pd.to_datetime(df2['ISO_TIME'], format='%Y-%m-%d').dt.year

# %%
# month = pd.to_datetime(df2['ISO_TIME'], format='%Y-%m-%d').dt.month

# %%
# day = pd.to_datetime(df2['ISO_TIME'], format='%Y-%m-%d').dt.day

# %%
# ee = pd.to_datetime(df2['ISO_TIME'], format='%Y-%m-%d').dt.time

# %%
# hour = pd.to_datetime(ee, format='%H:%M:%S').dt.hour

# %%
# df2['ISO_TIME'] = hour

# %%
# for i in df2.ISO_TIME:
#   if i ==0:
#    df2['Lat +6'] = df2['lat']
#    df2['Lon +6'] = df2['lon']

# %%
df2=df

# %%
df2['Lat +6'].fillna(method='ffill', inplace=True)
df2['Lon +6'].fillna(method='ffill', inplace=True)

# %%
df2
# Out:
#       NUMBER             ISO_TIME    lat    lon  q_eye_150  q_eye_500  \
# 0          1  1978-11-19 00:00:00   6.75  90.75   0.000011   0.004364
# 1          1  1978-11-19 03:00:00   7.00  90.50   0.000011   0.005096
# 2          1  1978-11-19 06:00:00   7.00  90.50   0.000012   0.005281
# 3          1  1978-11-19 09:00:00   7.50  90.25   0.000012   0.005514
# 4          1  1978-11-19 12:00:00   7.50  90.00   0.000011   0.005361
# ...      ...                  ...    ...    ...        ...        ...
# 1824      58  2021-12-04 18:00:00  17.00  84.25   0.000016   0.002354
# 1825      58  2021-12-04 21:00:00  17.25  84.50   0.000015   0.002231
# 1826      58  2021-12-05 00:00:00  18.00  84.50   0.000014   0.001984
# 1827      58  2021-12-05 03:00:00  18.25  84.50   0.000014   0.000942
# 1828      58  2021-12-05 06:00:00  18.50  84.50   0.000015   0.001061
#
#       q_eye_850   r_eye_150   r_eye_500   r_eye_550  ...  T-12_93_18_sst  \
# 0      0.000011   99.773224   87.319725   99.773224  ...      300.817596
# 1      0.000011   97.561157  100.889244   97.561157  ...      300.817596
# 2      0.000012   97.990585   99.541031   97.990585  ...      300.817596
# 3      0.000012   98.904373  100.814346   98.904373  ...      300.817596
# 4      0.000011   98.951813   97.860756   98.951813  ...      300.627380
# ...         ...         ...         ...         ...  ...             ...
# 1824   0.000016  100.889832   40.162926  100.889832  ...      302.722717
# 1825   0.000015   98.258652   36.168449   98.258652  ...      302.722717
# 1826   0.000014   90.667793   30.521656   90.667793  ...      302.722717
# 1827   0.000014   93.255341   17.373974   93.255341  ...      302.722717
# 1828   0.000015   91.804787   16.828655   91.804787  ...      302.722717
#
#       T-12_96_0_sst  T-12_96_6_sst  T-12_96_9_sst  T-12_96_12_sst  \
# 0        302.189789     301.535431     301.185730      301.064728
# 1        302.189789     301.535431     301.185730      301.064728
# 2        302.189789     301.535431     301.185730      301.064728
# 3        302.189789     301.535431     301.185730      301.064728
# 4        302.158661     301.436127     301.069824      300.942902
# ...             ...            ...            ...             ...
# 1824     302.218842     302.130829     301.951263      301.852570
# 1825     302.218842     302.130829     301.951263      301.852570
# 1826     302.218842     302.130829     301.951263      301.852570
# 1827     302.218842     302.130829     301.951263      301.852570
# 1828     302.218842     302.130829     301.951263      301.852570
#
#       T-12_96_15_sst  T-12_99_0_sst  T-12_99_6_sst  Lat +6  Lon +6
# 0         300.869385     302.642883     301.879181    7.00   90.50
# 1         300.869385     302.642883     301.879181    7.50   90.25
# 2         300.869385     302.642883     301.879181    7.50   90.00
# 3         300.869385     302.642883     301.879181    7.50   90.25
# 4         300.720123     302.554230     301.892090    7.75   89.75
# ...              ...            ...            ...     ...     ...
# 1824      302.243225     302.636749     302.461884   18.00   84.50
# 1825      302.243225     302.636749     302.461884   18.25   84.50
# 1826      302.243225     302.636749     302.461884   18.50   84.50
# 1827      302.243225     302.636749     302.461884   18.50   84.50
# 1828      302.243225     302.636749     302.461884   18.50   84.50
#
# [1829 rows x 1444 columns]

# %%
#select features and target
X = df2.iloc[:, :-2].values #for 6 hours prediction
Y=np.column_stack((df2['Lon +6'],df2['Lat +6']))

# %%
X[:,1]
# Out:
# array(['1978-11-19 00:00:00', '1978-11-19 03:00:00',
#        '1978-11-19 06:00:00', ..., '2021-12-05 00:00:00',
#        '2021-12-05 03:00:00', '2021-12-05 06:00:00'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le_date=LabelEncoder()
X[:,1]=le_date.fit_transform(X[:,1])

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan,strategy='mean')
X = imputer.fit_transform(X)
Y = imputer.fit_transform(Y)

# %%
X
# Out:
# array([[1.00000000e+00, 0.00000000e+00, 6.75000000e+00, ...,
#         3.00869385e+02, 3.02642883e+02, 3.01879181e+02],
#        [1.00000000e+00, 1.00000000e+00, 7.00000000e+00, ...,
#         3.00869385e+02, 3.02642883e+02, 3.01879181e+02],
#        [1.00000000e+00, 2.00000000e+00, 7.00000000e+00, ...,
#         3.00869385e+02, 3.02642883e+02, 3.01879181e+02],
#        ...,
#        [5.80000000e+01, 1.82600000e+03, 1.80000000e+01, ...,
#         3.02243225e+02, 3.02636749e+02, 3.02461884e+02],
#        [5.80000000e+01, 1.82700000e+03, 1.82500000e+01, ...,
#         3.02243225e+02, 3.02636749e+02, 3.02461884e+02],
#        [5.80000000e+01, 1.82800000e+03, 1.85000000e+01, ...,
#         3.02243225e+02, 3.02636749e+02, 3.02461884e+02]])

# %%
# feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
print(X)
print("-----------------------------------------------------------------")
print(Y)
# Out:
# [[-1.70736408 -1.73110407 -1.54287868 ... -1.29134049  0.63338833
#   -1.00327024]
#  [-1.70736408 -1.72921009 -1.47636619 ... -1.29134049  0.63338833
#   -1.00327024]
#  [-1.70736408 -1.7273161  -1.47636619 ... -1.29134049  0.63338833
#   -1.00327024]
#  ...
#  [ 1.74649006  1.7273161   1.45018304 ... -0.01587718  0.62210849
#   -0.20321311]
#  [ 1.74649006  1.72921009  1.51669552 ... -0.01587718  0.62210849
#   -0.20321311]
#  [ 1.74649006  1.73110407  1.58320801 ... -0.01587718  0.62210849
#   -0.20321311]]
# -----------------------------------------------------------------
# [[90.5   7.  ]
#  [90.25  7.5 ]
#  [90.    7.5 ]
#  ...
#  [84.5  18.5 ]
#  [84.5  18.5 ]
#  [84.5  18.5 ]]

# %%
cyclone_number = 45

# Get the index of the specific cyclone in New_df
index_number =df2.index[df2['NUMBER'] == cyclone_number].tolist()

k=index_number[-1]+1
# Print the index number
print("Last index number of Cyclone :"+str(cyclone_number) +' is',index_number[-1],'and k =',k)
# Out:
# Last index number of Cyclone :45 is 1469 and k = 1470

# %%
# Splitting without randomize
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
# k = 2050 #index for 55'th cyclone

X_train = X[:k,:]
X_test = X[k:,:]

Y_train = Y[:k]
Y_test= Y[k:]

# %%
# # Assuming you have a Pandas DataFrame named 'df'
# # Shape of df: (num_samples, num_features)

# # Convert DataFrame to NumPy array
# data_array1 = X_train

# # Reshape the 2D array to a 3D array for Conv1D
# X_train1 = np.expand_dims(data_array1, axis=2)
# # Shape of data_conv1d: (num_samples, num_features, 1)

# %%
# # Assuming you have a Pandas DataFrame named 'df'
# # Shape of df: (num_samples, num_features)

# # Convert DataFrame to NumPy array
# data_array2 = X_test

# # Reshape the 2D array to a 3D array for Conv1D
# X_test1 = np.expand_dims(data_array2, axis=2)
# # Shape of data_conv1d: (num_samples, num_features, 1)

# %%
# X_train1.ndim
# Out:
# 3

# %%
#  X_train1.shape[1] 
# print(X_train1.shape[1])
# Out:
# 1442

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Dense
num_features = X_train1.shape[1] 
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=5,
                 strides=1, padding="causal",
                 activation="relu",
                 input_shape=[num_features, 1]))
model.add(LSTM(512))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=["mean_squared_error"])
history = model.fit(X_train1, Y_train, epochs=100, batch_size=24, verbose=2, validation_split=0.2)
# Out:
# Epoch 1/100
# 2023-09-01 12:15:06.240101: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-09-01 12:15:06.240963: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-09-01 12:15:06.241720: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 13
#      10 model.add(Dense(1))
#      12 model.compile(loss='mean_squared_error', optimizer='adam', metrics=["mean_squared_error"])
# ---> 13 history = model.fit(X_train1, Y_train, epochs=100, batch_size=24, verbose=2, validation_split=0.2)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /tmp/__autograph_generated_filek5dkdb4c.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "/home/sanjid/anaconda3/lib/python3.11/site-packages/keras/engine/training.py", line 1284, in train_function  *
#         return step_function(self, iterator)
#     File "/home/sanjid/anaconda3/lib/python3.11/site-packages/keras/engine/training.py", line 1268, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/sanjid/anaconda3/lib/python3.11/site-packages/keras/engine/training.py", line 1249, in run_step  **
#         outputs = model.train_step(data)
#     File "/home/sanjid/anaconda3/lib/python3.11/site-packages/keras/engine/training.py", line 1050, in train_step
#         y_pred = self(x, training=True)
#     File "/home/sanjid/anaconda3/lib/python3.11/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/home/sanjid/anaconda3/lib/python3.11/site-packages/keras/engine/input_spec.py", line 280, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Exception encountered when calling layer 'sequential_5' (type Sequential).
#
#     Input 0 of layer "conv1d_4" is incompatible with the layer: expected axis -1 of input shape to have value 3, but received input with shape (24, 1442, 1)
#
#     Call arguments received by layer 'sequential_5' (type Sequential):
#       • inputs=tf.Tensor(shape=(24, 1442, 1), dtype=float32)
#       • training=True
#       • mask=None

# %%
# Save the model
# model_conv1D.save('/content/drive/MyDrive/Colab Notebooks/ML_TCBOB/Scripts/Models/conv1d with callbacks')

# # To load the model later:
# # loaded_model = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/ML_TCBOB/Scripts/Models/conv1d with callbacks')

# %% [markdown]
# # Model with MirroredStratagey

# %%
import tensorflow as tf



# Define the MirroredStrategy
strategy = tf.distribute.MirroredStrategy()

def build_conv1D_model():
    n_timesteps = X_train1.shape[1]
    n_features  = X_train1.shape[2]

    with strategy.scope():  # Wrap the model creation in the strategy.scope()
        model = keras.Sequential(name="model_conv1D")
        model.add(keras.layers.Input(shape=(n_timesteps, n_features)))
        model.add(keras.layers.Conv1D(filters=64, kernel_size=24, activation='relu', name="Conv1D_3"))
        model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)))
        model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=False)))
        model.add(keras.layers.Flatten())
        model.add(keras.layers.Dense(32, activation='linear', name="Dense_1"))
        model.add(keras.layers.Dense(2, name="Dense_2"))

        optimizer = tf.keras.optimizers.RMSprop(lr=1e-5, momentum=0.9)

        model.compile(loss="mse", optimizer=optimizer, metrics=['mae'])

    return model

model_conv1D = build_conv1D_model()
model_conv1D.summary()

# Now, train the model without the callbacks
with strategy.scope():
    history = model_conv1D.fit(X_train1, Y_train, epochs=100, batch_size=24, verbose=1, validation_split=0.2)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Model: "model_conv1D"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv1D_3 (Conv1D)           (None, 1419, 64)          1600
#
#  bidirectional_2 (Bidirectio  (None, 1419, 64)         24832
#  nal)
#
#  bidirectional_3 (Bidirectio  (None, 64)               24832
#  nal)
#
#  flatten_1 (Flatten)         (None, 64)                0
#
#  Dense_1 (Dense)             (None, 32)                2080
#
#  Dense_2 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 53,410
# Trainable params: 53,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 49/49 [==============================] - 16s 173ms/step - loss: 661.1675 - mae: 15.2938 - val_loss: 28.5355 - val_mae: 4.7469
# Epoch 2/100
# 49/49 [==============================] - 8s 167ms/step - loss: 16.9281 - mae: 3.3366 - val_loss: 22.5250 - val_mae: 3.6544
# Epoch 3/100
# 49/49 [==============================] - 7s 140ms/step - loss: 16.4012 - mae: 3.2968 - val_loss: 14.4327 - val_mae: 3.0474
# Epoch 4/100
# 49/49 [==============================] - 8s 166ms/step - loss: 16.0681 - mae: 3.2580 - val_loss: 16.1458 - val_mae: 2.9413
# Epoch 5/100
# 49/49 [==============================] - 8s 171ms/step - loss: 16.2759 - mae: 3.2853 - val_loss: 16.0525 - val_mae: 2.9735
# Epoch 6/100
# 49/49 [==============================] - 8s 162ms/step - loss: 15.0215 - mae: 3.0840 - val_loss: 9.7632 - val_mae: 2.4371
# Epoch 7/100
# 49/49 [==============================] - 7s 152ms/step - loss: 8.6186 - mae: 2.2404 - val_loss: 10.2127 - val_mae: 2.3049
# Epoch 8/100
# 49/49 [==============================] - 8s 169ms/step - loss: 5.1343 - mae: 1.7077 - val_loss: 5.5907 - val_mae: 1.4452
# Epoch 9/100
# 49/49 [==============================] - 8s 159ms/step - loss: 1.6156 - mae: 0.9077 - val_loss: 4.3537 - val_mae: 1.2192
# Epoch 10/100
# 49/49 [==============================] - 7s 141ms/step - loss: 1.1973 - mae: 0.7863 - val_loss: 4.3292 - val_mae: 1.2495
# Epoch 11/100
# 49/49 [==============================] - 8s 165ms/step - loss: 0.9517 - mae: 0.6564 - val_loss: 5.0361 - val_mae: 1.4864
# Epoch 12/100
# 49/49 [==============================] - 7s 136ms/step - loss: 0.9894 - mae: 0.6957 - val_loss: 4.0086 - val_mae: 0.9999
# Epoch 13/100
# 49/49 [==============================] - 8s 167ms/step - loss: 1.0818 - mae: 0.7304 - val_loss: 4.1824 - val_mae: 1.0590
# Epoch 14/100
# 49/49 [==============================] - 7s 137ms/step - loss: 0.8071 - mae: 0.5977 - val_loss: 4.0577 - val_mae: 1.0834
# Epoch 15/100
# 49/49 [==============================] - 8s 166ms/step - loss: 0.7865 - mae: 0.5970 - val_loss: 3.8921 - val_mae: 1.0168
# Epoch 16/100
# 49/49 [==============================] - 9s 177ms/step - loss: 0.7816 - mae: 0.5904 - val_loss: 4.7526 - val_mae: 1.1737
# Epoch 17/100
# 49/49 [==============================] - 8s 164ms/step - loss: 0.7079 - mae: 0.5852 - val_loss: 4.4265 - val_mae: 1.1470
# Epoch 18/100
# 49/49 [==============================] - 7s 149ms/step - loss: 0.6087 - mae: 0.5228 - val_loss: 4.1695 - val_mae: 1.1013
# Epoch 19/100
# 49/49 [==============================] - 8s 159ms/step - loss: 0.6934 - mae: 0.5825 - val_loss: 5.2031 - val_mae: 1.3726
# Epoch 20/100
# 49/49 [==============================] - 7s 154ms/step - loss: 0.5635 - mae: 0.5330 - val_loss: 4.3947 - val_mae: 1.0851
# Epoch 21/100
# 49/49 [==============================] - 7s 150ms/step - loss: 0.5711 - mae: 0.5164 - val_loss: 4.7946 - val_mae: 1.1883
# Epoch 22/100
# 49/49 [==============================] - 8s 161ms/step - loss: 0.7249 - mae: 0.6480 - val_loss: 4.8543 - val_mae: 1.1289
# Epoch 23/100
# 49/49 [==============================] - 7s 143ms/step - loss: 0.5246 - mae: 0.5298 - val_loss: 4.5938 - val_mae: 1.0108
# Epoch 24/100
# 49/49 [==============================] - 8s 173ms/step - loss: 0.6352 - mae: 0.5799 - val_loss: 5.5249 - val_mae: 1.1676
# Epoch 25/100
# 49/49 [==============================] - 7s 141ms/step - loss: 0.5789 - mae: 0.5587 - val_loss: 6.0473 - val_mae: 1.4140
# Epoch 26/100
# 49/49 [==============================] - 8s 169ms/step - loss: 0.4385 - mae: 0.4909 - val_loss: 4.8585 - val_mae: 1.1173
# Epoch 27/100
# 49/49 [==============================] - 7s 139ms/step - loss: 0.3927 - mae: 0.4439 - val_loss: 5.4703 - val_mae: 1.2233
# Epoch 28/100
# 49/49 [==============================] - 10s 209ms/step - loss: 0.3713 - mae: 0.4592 - val_loss: 4.6675 - val_mae: 1.0980
# Epoch 29/100
# 49/49 [==============================] - 7s 137ms/step - loss: 0.3825 - mae: 0.4594 - val_loss: 5.2880 - val_mae: 1.1160
# Epoch 30/100
# 49/49 [==============================] - 8s 170ms/step - loss: 0.3743 - mae: 0.4567 - val_loss: 4.0669 - val_mae: 1.0050
# Epoch 31/100
# 49/49 [==============================] - 7s 139ms/step - loss: 0.3590 - mae: 0.4471 - val_loss: 5.6122 - val_mae: 1.2196
# Epoch 32/100
# 49/49 [==============================] - 8s 166ms/step - loss: 0.4357 - mae: 0.4981 - val_loss: 6.3432 - val_mae: 1.3775
# Epoch 33/100
# 49/49 [==============================] - 7s 138ms/step - loss: 0.3284 - mae: 0.4343 - val_loss: 6.2410 - val_mae: 1.2122
# Epoch 34/100
# 49/49 [==============================] - 8s 168ms/step - loss: 0.5836 - mae: 0.5490 - val_loss: 6.1569 - val_mae: 1.4143
# Epoch 35/100
# 49/49 [==============================] - 7s 137ms/step - loss: 0.3251 - mae: 0.4364 - val_loss: 5.8446 - val_mae: 1.2799
# Epoch 36/100
# 49/49 [==============================] - 8s 165ms/step - loss: 0.3251 - mae: 0.4322 - val_loss: 5.7836 - val_mae: 1.2141
# Epoch 37/100
# 49/49 [==============================] - 7s 138ms/step - loss: 0.3644 - mae: 0.4417 - val_loss: 5.2841 - val_mae: 1.1662
# Epoch 38/100
# 49/49 [==============================] - 8s 168ms/step - loss: 0.4369 - mae: 0.4845 - val_loss: 4.6058 - val_mae: 1.1212
# Epoch 39/100
# 49/49 [==============================] - 7s 137ms/step - loss: 0.3333 - mae: 0.4267 - val_loss: 6.3681 - val_mae: 1.2490
# Epoch 40/100
# 49/49 [==============================] - 8s 166ms/step - loss: 0.3123 - mae: 0.4305 - val_loss: 4.7864 - val_mae: 1.2661
# Epoch 41/100
# 49/49 [==============================] - 7s 136ms/step - loss: 0.3888 - mae: 0.4573 - val_loss: 6.4075 - val_mae: 1.3491
# Epoch 42/100
# 49/49 [==============================] - 8s 166ms/step - loss: 0.3455 - mae: 0.4333 - val_loss: 6.2031 - val_mae: 1.2910
# Epoch 43/100
# 34/49 [===================>..........] - ETA: 1s - loss: 0.2670 - mae: 0.4106

# %% [markdown]
# # Saving and loading the model

# %%
# # # Save the model
# # model_conv1D.save('/content/drive/MyDrive/Colab Notebooks/ML_TCBOB/Scripts/Models/conv1d with mirror')

# # # To load the model later:
# loaded_model = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/ML_TCBOB/Scripts/Models/conv1d with mirror')

# %%
# import matplotlib.pyplot as plt
# # print(history.history.keys())

# # summarize history for accuracy
# #with plt.style.context('ggplot'):
# plt.figure(dpi=110)
# plt.plot(history.history['mae'])
# plt.plot(history.history['val_mae'])
# plt.title('Mean Absolute error')
# plt.ylabel('Error')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Validation'], loc='upper left')
# plt.show()


# # summarize history for loss
# #with plt.style.context('ggplot'):
# plt.figure(dpi=110)
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('Loss')
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['Train', 'Validation'], loc='upper right')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-e6e701ed06de> in <cell line: 7>()
#       5 #with plt.style.context('ggplot'):
#       6 plt.figure(dpi=110)
# ----> 7 plt.plot(history.history['mae'])
#       8 plt.plot(history.history['val_mae'])
#       9 plt.title('Mean Absolute error')
#
# NameError: name 'history' is not defined

# %% [markdown]
# # Using the loaded model

# %%
# Y_pred = model_conv1D.predict(X_test1)
Y_pred = loaded_model.predict(X_test1)

Y_pred = Y_pred
print(Y_pred[:10])
# Out:
# 12/12 [==============================] - 9s 65ms/step
# [[86.97031    7.3365254]
#  [87.61728    7.536393 ]
#  [87.52728    7.698462 ]
#  [87.19652    8.266476 ]
#  [85.89297    8.154513 ]
#  [85.60713    8.608715 ]
#  [85.23004    9.043444 ]
#  [84.7548     9.032315 ]
#  [84.35639    9.5562725]
#  [83.905716   9.625441 ]]

# %%
lon_test = Y_test[:,0]
lat_test = Y_test[:,1]

lon_pred = Y_pred[:,0]
lat_pred = Y_pred[:,1]

random_dataset = pd.DataFrame()
random_dataset['lon_test'] = lon_test
random_dataset['lat_test'] = lat_test

random_dataset['lon_pred'] = lon_pred
random_dataset['lat_pred'] = lat_pred
random_dataset['deviation'] = np.sqrt(((lon_test-lon_pred)**2)+ ((lat_test-lat_pred)**2))

print("  ")
print("The average error for the deviation is "+ str(random_dataset['deviation'].mean()))
print("  ")

random_dataset
# Out:
#
# The average error for the deviation is 0.4267003379724863
#      lon_test  lat_test   lon_pred   lat_pred  deviation
# 0       87.00      7.00  86.970306   7.336525   0.337833
# 1       87.50      7.25  87.617279   7.536393   0.309476
# 2       87.50      7.50  87.527283   7.698462   0.200329
# 3       87.25      8.25  87.196518   8.266476   0.055962
# 4       85.75      8.25  85.892967   8.154513   0.171922
# ..        ...       ...        ...        ...        ...
# 354     84.25     17.00  84.617577  17.057865   0.372103
# 355     84.50     17.25  84.930603  17.390596   0.452975
# 356     84.50     18.00  84.422165  18.020966   0.080609
# 357     84.50     18.25  84.441803  18.489178   0.246156
# 358     84.50     18.50  84.527061  18.798697   0.299920
#
# [359 rows x 5 columns]

# %%
plt.figure(figsize=(14,4))
plt.plot(lon_test, label='Lon Test')
plt.plot(lon_pred, label='Lon Predition')
plt.xlabel('Value index')
plt.ylabel('Longitude Value')
plt.ylim(80,100)
plt.title("Longitude prediction with ANN")
plt.legend()

plt.figure(figsize=(14,4))
plt.plot(lat_test, label='Lat Test')
plt.plot(lat_pred, label='Lat Predition')
plt.xlabel('Value index')
plt.ylabel('Latitude Value')
plt.ylim(5, 25)
plt.title("Latitude prediction with ANN")
plt.legend()

# %%
X_original_scale = sc.inverse_transform(X_test)
cyclone_number=X_original_scale[:,1]

lon_test = Y_test[:,0]
lat_test = Y_test[:,1]

lon_pred = Y_pred[:,0]
lat_pred = Y_pred[:,1]

random_dataset = pd.DataFrame()
random_dataset['cyclone_number'] = cyclone_number
random_dataset['lon_test'] = lon_test
random_dataset['lat_test'] = lat_test

random_dataset['lon_pred'] = lon_pred
random_dataset['lat_pred'] = lat_pred
random_dataset['deviation'] = np.sqrt(((lon_test-lon_pred)**2)+ ((lat_test-lat_pred)**2))

print("  ")
print("The average error for the deviation is "+ str(random_dataset['deviation'].mean()))
print("  ")

random_dataset
# Out:
#
# The average error for the deviation is 0.4267003379724863
#      cyclone_number  lon_test  lat_test   lon_pred   lat_pred  deviation
# 0              46.0     87.00      7.00  86.970306   7.336525   0.337833
# 1              46.0     87.50      7.25  87.617279   7.536393   0.309476
# 2              46.0     87.50      7.50  87.527283   7.698462   0.200329
# 3              46.0     87.25      8.25  87.196518   8.266476   0.055962
# 4              46.0     85.75      8.25  85.892967   8.154513   0.171922
# ..              ...       ...       ...        ...        ...        ...
# 354            58.0     84.25     17.00  84.617577  17.057865   0.372103
# 355            58.0     84.50     17.25  84.930603  17.390596   0.452975
# 356            58.0     84.50     18.00  84.422165  18.020966   0.080609
# 357            58.0     84.50     18.25  84.441803  18.489178   0.246156
# 358            58.0     84.50     18.50  84.527061  18.798697   0.299920
#
# [359 rows x 6 columns]

# %%
# !apt-get install -qq libgdal-dev libproj-dev
# #!pip install --no-binary shapely shapely
# !pip install --no-binary shapely shapely --force
# !pip install cartopy
# import cartopy.crs as ccrs
# import cartopy.feature as cfeature
# import matplotlib.pyplot as plt

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import cartopy.crs as ccrs

# fig, axs = plt.subplots(3, 4, figsize=(16, 18), dpi=100, subplot_kw={'projection': ccrs.PlateCarree()})

# for i in range(3):
#     for j in range(4):
#         # Taking the cyclone number from input
#         cyclone_number = i * 4 + j + 45

#         # Separating the data for the desired cyclone
#         cyclone_data = random_dataset[random_dataset['cyclone_number'] == float(cyclone_number)]
#         # cyclone_data = cyclone_data.drop(cyclone_data.index[0]) #removing the last row as it creates problem

#         # Plotting the cyclone data
#         axs[i, j].plot(cyclone_data['lon_test'], cyclone_data['lat_test'], '-o', markersize=2.5, transform=ccrs.PlateCarree())
#         axs[i, j].plot(cyclone_data['lon_pred'], cyclone_data['lat_pred'], '-o', markersize=2.5, transform=ccrs.PlateCarree())
#         axs[i, j].set_extent([70, 100, 5, 30], crs=ccrs.PlateCarree())
#         axs[i, j].coastlines(linewidth=1.4)
#         axs[i, j].gridlines(draw_labels=True)
#         axs[i, j].set_title(f"Cyclone {cyclone_number}")
#         # axs[i,j].legend(['Test', 'Prediction'], loc='upper left')

# # Set the overall title for the subplot
# fig.suptitle("6h Prediction no prev feature", fontsize=20, y=1)
# fig.legend(['Test', 'Prediction'], loc='upper left')

# # Adjust spacing between subplots
# fig.tight_layout()

# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

def plot_cyclone_data(cyclone_data_list):
    num_cyclones = len(cyclone_data_list)
    num_rows = (num_cyclones + 3) // 4  # Round up to the nearest multiple of 4
    fig, axs = plt.subplots(num_rows, 4, figsize=(24, 18), dpi=150, subplot_kw={'projection': ccrs.PlateCarree()})
    axs = axs.ravel()

    for i, cyclone_data in enumerate(cyclone_data_list):
        ax = axs[i]
        ax.plot(cyclone_data['lon_test'], cyclone_data['lat_test'], '-o', markersize=2.5, transform=ccrs.PlateCarree())
        ax.plot(cyclone_data['lon_pred'], cyclone_data['lat_pred'], '-o', markersize=2.5, transform=ccrs.PlateCarree())
        ax.set_extent([78, 100, 0, 30], crs=ccrs.PlateCarree())
        ax.coastlines(linewidth=1.4)
        ax.gridlines(draw_labels=True)
        ax.set_title(f"Cyclone {cyclone_data['cyclone_number'].iloc[0]}")
        ax.legend(['Test', 'Prediction'], loc='upper left')

    # Adjust spacing between subplots
    fig.tight_layout()

    plt.show()

# Taking the cyclone numbers from 46 to 58
cyclone_numbers = list(range(46, 58))

# Separating the data for the desired cyclones
cyclone_data_list = [random_dataset[random_dataset['cyclone_number'] == float(cyclone_number)] for cyclone_number in cyclone_numbers]

# Plotting the cyclone data
plot_cyclone_data(cyclone_data_list)

# %%
## take from lat from 78

# %%
def plot_cyclone_data(cyclone_data):
    fig = plt.figure(figsize=(20, 12))
    ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
    ax.plot(cyclone_data['lon_test'], cyclone_data['lat_test'], '-o', markersize=5, transform=ccrs.PlateCarree())
    ax.plot(cyclone_data['lon_pred'], cyclone_data['lat_pred'], '-o', markersize=5, transform=ccrs.PlateCarree())
    ax.set_extent([80, 100, 0, 30], crs=ccrs.PlateCarree())
    ax.coastlines(linewidth=1.4)
    ax.gridlines(draw_labels=True)
    plt.legend(['Test', 'Prediction'], loc='upper left')
    plt.show()


# Taking the cyclone number from input
cyclone_number = input("Enter cyclone number: ")

# Separating the data for the desired cyclone
cyclone_data = random_dataset[random_dataset['cyclone_number'] == float(cyclone_number)]

# Plotting the cyclone data

plot_cyclone_data(cyclone_data)

# %% [markdown]
# # Run this cell for same initial point

# %%
# fig, axs = plt.subplots(4, 4, figsize=(16, 18), dpi=100, subplot_kw={'projection': ccrs.PlateCarree()})

# for i in range(4):
#     for j in range(4):
#         # Taking the cyclone number from input
#         cyclone_number = i*4 + j + 53

#         # Separating the data for the desired cyclone
#         cyclone_data = random_dataset[random_dataset['cyclone_number'] == float(cyclone_number)]

#         # Get the first point of lat_test and lon_test
#         first_lat_test = cyclone_data['lat_test'].iloc[0]
#         first_lon_test = cyclone_data['lon_test'].iloc[0]
#         # Create a new DataFrame with the newly added columns
#         plot_df=pd.DataFrame({
#             'lat_pred':[first_lat_test]+cyclone_data['lat_pred'].tolist(),
#             'lon_pred':[first_lon_test]+cyclone_data['lon_pred'].tolist(),
#         })

#         # Plotting the cyclone data
#         axs[i,j].plot(cyclone_data['lon_test'], cyclone_data['lat_test'], '-o', markersize=2.5, transform=ccrs.PlateCarree())
#         axs[i,j].plot(plot_df['lon_pred'], plot_df['lat_pred'], '-o', markersize=2.5, transform=ccrs.PlateCarree())
#         axs[i,j].set_extent([80, 100, 5, 30], crs=ccrs.PlateCarree())
#         axs[i,j].coastlines(linewidth=1.4)
#         axs[i,j].gridlines(draw_labels=True)
#         axs[i,j].set_title(f"Cyclone {cyclone_number}")
# # Set the overall title for the subplot
# fig.suptitle("6h Prediction no prev feature", fontsize=20, y=1)
# fig.legend(['Test', 'Prediction'], loc='upper left')

# # Adjust spacing between subplots
# fig.tight_layout()
