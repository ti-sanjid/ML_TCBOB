# %%
# !pip 
import pandas as pd
import numpy as np
from datetime import datetime
import tensorflow as tf
from tensorflow import keras

import numpy as np

print(tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 from datetime import datetime
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ML_TCBOB/PD/rearranged_final[date: 3rd august 2023].csv")

# %%
df
# Out:
#       NUMBER             ISO_TIME    lat    lon  q_eye_150  q_eye_500  \
# 0          1  1978-11-19 00:00:00   6.75  90.75   0.000011   0.004364
# 1          1  1978-11-19 03:00:00   7.00  90.50   0.000011   0.005096
# 2          1  1978-11-19 06:00:00   7.00  90.50   0.000012   0.005281
# 3          1  1978-11-19 09:00:00   7.50  90.25   0.000012   0.005514
# 4          1  1978-11-19 12:00:00   7.50  90.00   0.000011   0.005361
# ...      ...                  ...    ...    ...        ...        ...
# 1824      58  2021-12-04 18:00:00  17.00  84.25   0.000016   0.002354
# 1825      58  2021-12-04 21:00:00  17.25  84.50   0.000015   0.002231
# 1826      58  2021-12-05 00:00:00  18.00  84.50   0.000014   0.001984
# 1827      58  2021-12-05 03:00:00  18.25  84.50   0.000014   0.000942
# 1828      58  2021-12-05 06:00:00  18.50  84.50   0.000015   0.001061
#
#       q_eye_850   r_eye_150   r_eye_500   r_eye_550  ...  T-12_93_18_sst  \
# 0      0.000011   99.773224   87.319725   99.773224  ...      300.817596
# 1      0.000011   97.561157  100.889244   97.561157  ...      300.817596
# 2      0.000012   97.990585   99.541031   97.990585  ...      300.817596
# 3      0.000012   98.904373  100.814346   98.904373  ...      300.817596
# 4      0.000011   98.951813   97.860756   98.951813  ...      300.627380
# ...         ...         ...         ...         ...  ...             ...
# 1824   0.000016  100.889832   40.162926  100.889832  ...      302.722717
# 1825   0.000015   98.258652   36.168449   98.258652  ...      302.722717
# 1826   0.000014   90.667793   30.521656   90.667793  ...      302.722717
# 1827   0.000014   93.255341   17.373974   93.255341  ...      302.722717
# 1828   0.000015   91.804787   16.828655   91.804787  ...      302.722717
#
#       T-12_96_0_sst  T-12_96_6_sst  T-12_96_9_sst  T-12_96_12_sst  \
# 0        302.189789     301.535431     301.185730      301.064728
# 1        302.189789     301.535431     301.185730      301.064728
# 2        302.189789     301.535431     301.185730      301.064728
# 3        302.189789     301.535431     301.185730      301.064728
# 4        302.158661     301.436127     301.069824      300.942902
# ...             ...            ...            ...             ...
# 1824     302.218842     302.130829     301.951263      301.852570
# 1825     302.218842     302.130829     301.951263      301.852570
# 1826     302.218842     302.130829     301.951263      301.852570
# 1827     302.218842     302.130829     301.951263      301.852570
# 1828     302.218842     302.130829     301.951263      301.852570
#
#       T-12_96_15_sst  T-12_99_0_sst  T-12_99_6_sst  Lat +6  Lon +6
# 0         300.869385     302.642883     301.879181    7.00   90.50
# 1         300.869385     302.642883     301.879181    7.50   90.25
# 2         300.869385     302.642883     301.879181    7.50   90.00
# 3         300.869385     302.642883     301.879181    7.50   90.25
# 4         300.720123     302.554230     301.892090    7.75   89.75
# ...              ...            ...            ...     ...     ...
# 1824      302.243225     302.636749     302.461884   18.00   84.50
# 1825      302.243225     302.636749     302.461884   18.25   84.50
# 1826      302.243225     302.636749     302.461884   18.50   84.50
# 1827      302.243225     302.636749     302.461884     NaN     NaN
# 1828      302.243225     302.636749     302.461884     NaN     NaN
#
# [1829 rows x 1444 columns]

# %%
df2 = df.fillna(method="ffill")

# %%
df2.insert(loc = 0,
          column = 'index',
          value = df.index)

# %%
year = pd.to_datetime(df2['ISO_TIME'], format='%Y-%m-%d').dt.year

# %%
month = pd.to_datetime(df2['ISO_TIME'], format='%Y-%m-%d').dt.month

# %%
day = pd.to_datetime(df2['ISO_TIME'], format='%Y-%m-%d').dt.day

# %%
ee = pd.to_datetime(df2['ISO_TIME'], format='%Y-%m-%d').dt.time

# %%
hour = pd.to_datetime(ee, format='%H:%M:%S').dt.hour

# %%
df2['ISO_TIME'] = hour

# %%
for i in df2.ISO_TIME:
  if i ==0:
   df2['Lat +6'] = df2['lat']
   df2['Lon +6'] = df2['lon']

# %%
df2
# Out:
#       index  NUMBER  ISO_TIME    lat    lon  q_eye_150  q_eye_500  q_eye_850  \
# 0         0       1         0   6.75  90.75   0.000011   0.004364   0.000011
# 1         1       1         3   7.00  90.50   0.000011   0.005096   0.000011
# 2         2       1         6   7.00  90.50   0.000012   0.005281   0.000012
# 3         3       1         9   7.50  90.25   0.000012   0.005514   0.000012
# 4         4       1        12   7.50  90.00   0.000011   0.005361   0.000011
# ...     ...     ...       ...    ...    ...        ...        ...        ...
# 1824   1824      58        18  17.00  84.25   0.000016   0.002354   0.000016
# 1825   1825      58        21  17.25  84.50   0.000015   0.002231   0.000015
# 1826   1826      58         0  18.00  84.50   0.000014   0.001984   0.000014
# 1827   1827      58         3  18.25  84.50   0.000014   0.000942   0.000014
# 1828   1828      58         6  18.50  84.50   0.000015   0.001061   0.000015
#
#        r_eye_150   r_eye_500  ...  T-12_93_18_sst  T-12_96_0_sst  \
# 0      99.773224   87.319725  ...      300.817596     302.189789
# 1      97.561157  100.889244  ...      300.817596     302.189789
# 2      97.990585   99.541031  ...      300.817596     302.189789
# 3      98.904373  100.814346  ...      300.817596     302.189789
# 4      98.951813   97.860756  ...      300.627380     302.158661
# ...          ...         ...  ...             ...            ...
# 1824  100.889832   40.162926  ...      302.722717     302.218842
# 1825   98.258652   36.168449  ...      302.722717     302.218842
# 1826   90.667793   30.521656  ...      302.722717     302.218842
# 1827   93.255341   17.373974  ...      302.722717     302.218842
# 1828   91.804787   16.828655  ...      302.722717     302.218842
#
#       T-12_96_6_sst  T-12_96_9_sst  T-12_96_12_sst  T-12_96_15_sst  \
# 0        301.535431     301.185730      301.064728      300.869385
# 1        301.535431     301.185730      301.064728      300.869385
# 2        301.535431     301.185730      301.064728      300.869385
# 3        301.535431     301.185730      301.064728      300.869385
# 4        301.436127     301.069824      300.942902      300.720123
# ...             ...            ...             ...             ...
# 1824     302.130829     301.951263      301.852570      302.243225
# 1825     302.130829     301.951263      301.852570      302.243225
# 1826     302.130829     301.951263      301.852570      302.243225
# 1827     302.130829     301.951263      301.852570      302.243225
# 1828     302.130829     301.951263      301.852570      302.243225
#
#       T-12_99_0_sst  T-12_99_6_sst  Lat +6  Lon +6
# 0        302.642883     301.879181    6.75   90.75
# 1        302.642883     301.879181    7.00   90.50
# 2        302.642883     301.879181    7.00   90.50
# 3        302.642883     301.879181    7.50   90.25
# 4        302.554230     301.892090    7.50   90.00
# ...             ...            ...     ...     ...
# 1824     302.636749     302.461884   17.00   84.25
# 1825     302.636749     302.461884   17.25   84.50
# 1826     302.636749     302.461884   18.00   84.50
# 1827     302.636749     302.461884   18.25   84.50
# 1828     302.636749     302.461884   18.50   84.50
#
# [1829 rows x 1445 columns]

# %%
#select features and target
X = df2.iloc[:, :-2].values #for 6 hours prediction
y1 = (df2['Lon +6'])
y2 = (df2['Lat +6'])

# %%
Y = np.column_stack((y1, y2))

# %%
# feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
print(X)
print("-----------------------------------------------------------------")
print(Y)
# Out:
# [[-1.73110407 -1.70736408 -1.50463563 ... -1.29134049  0.63338833
#   -1.00327024]
#  [-1.72921009 -1.70736408 -1.07120767 ... -1.29134049  0.63338833
#   -1.00327024]
#  [-1.7273161  -1.70736408 -0.63777972 ... -1.29134049  0.63338833
#   -1.00327024]
#  ...
#  [ 1.7273161   1.74649006 -1.50463563 ... -0.01587718  0.62210849
#   -0.20321311]
#  [ 1.72921009  1.74649006 -1.07120767 ... -0.01587718  0.62210849
#   -0.20321311]
#  [ 1.73110407  1.74649006 -0.63777972 ... -0.01587718  0.62210849
#   -0.20321311]]
# -----------------------------------------------------------------
# [[90.75  6.75]
#  [90.5   7.  ]
#  [90.5   7.  ]
#  ...
#  [84.5  18.  ]
#  [84.5  18.25]
#  [84.5  18.5 ]]

# %%
cyclone_number = 45

# Get the index of the specific cyclone in New_df
index_number =df2.index[df2['NUMBER'] == cyclone_number].tolist()

k=index_number[-1]+1
# Print the index number
print("Last index number of Cyclone",index_number[-1],'and k =',k)
# Out:
# Last index number of Cyclone 1469 and k = 1470

# %%
# Splitting without randomize
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
# k = 2050 #index for 55'th cyclone

X_train = X[:k,:]
X_test = X[k:,:]

Y_train = Y[:k]
Y_test= Y[k:]

# %%
# Assuming you have a Pandas DataFrame named 'df'
# Shape of df: (num_samples, num_features)

# Convert DataFrame to NumPy array
data_array1 = X_train

# Reshape the 2D array to a 3D array for Conv1D
X_train1 = np.expand_dims(data_array1, axis=2)
# Shape of data_conv1d: (num_samples, num_features, 1)

# %%
# Assuming you have a Pandas DataFrame named 'df'
# Shape of df: (num_samples, num_features)

# Convert DataFrame to NumPy array
data_array2 = X_test

# Reshape the 2D array to a 3D array for Conv1D
X_test1 = np.expand_dims(data_array2, axis=2)
# Shape of data_conv1d: (num_samples, num_features, 1)

# %%
# def build_conv1D_model():

#   n_timesteps = X_train1.shape[1]
#   n_features  = X_train1.shape[2]
#   model = keras.Sequential(name="model_conv1D")
#   model.add(keras.layers.Input(shape=(n_timesteps,n_features)))
#   #model.add(keras.layers.Conv1D(filters=512, kernel_size=7, activation='relu', name="Conv1D_1"))
#   #model.add(keras.layers.Dropout(0.6))
#   #model.add(keras.layers.Conv1D(filters=256, kernel_size=3, activation='relu', name="Conv1D_2"))

#   model.add(keras.layers.Conv1D(filters=64, kernel_size=24, activation='relu', name="Conv1D_3"))
#   model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)))
#   model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=False)))

#   model.add(keras.layers.Flatten())
#   model.add(keras.layers.Dense(32, activation='linear', name="Dense_1"))
#   model.add(keras.layers.Dense(2, name="Dense_2"))


#   optimizer = tf.keras.optimizers.RMSprop(lr=1e-5, momentum=0.9)

#   model.compile(loss="mse",optimizer=optimizer,metrics=['mae'])
#   return model

# model_conv1D = build_conv1D_model()
# model_conv1D.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Model: "model_conv1D"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv1D_3 (Conv1D)           (None, 1420, 64)          1600
#
#  bidirectional_6 (Bidirectio  (None, 1420, 64)         24832
#  nal)
#
#  bidirectional_7 (Bidirectio  (None, 64)               24832
#  nal)
#
#  flatten_3 (Flatten)         (None, 64)                0
#
#  Dense_1 (Dense)             (None, 32)                2080
#
#  Dense_2 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 53,410
# Trainable params: 53,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
# import keras.callbacks
# my_callbacks = [
#     tf.keras.callbacks.EarlyStopping(patience=15),
#     tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
#     tf.keras.callbacks.TensorBoard(log_dir='./logs'),
# ]
# # Store training stats
# history = model_conv1D.fit(X_train1, Y_train, epochs=50, batch_size=24, verbose=1, validation_split=0.2, callbacks=my_callbacks)
# Out:
# Epoch 1/50
# 49/49 [==============================] - 18s 191ms/step - loss: 712.6420 - mae: 16.6835 - val_loss: 22.6151 - val_mae: 3.7355
# Epoch 2/50
# 49/49 [==============================] - 10s 196ms/step - loss: 15.9810 - mae: 3.2436 - val_loss: 17.3703 - val_mae: 3.1936
# Epoch 3/50
# 49/49 [==============================] - 9s 188ms/step - loss: 15.4438 - mae: 3.2082 - val_loss: 15.3487 - val_mae: 2.9924
# Epoch 4/50
# 49/49 [==============================] - 7s 150ms/step - loss: 15.2119 - mae: 3.1775 - val_loss: 13.1211 - val_mae: 2.9160
# Epoch 5/50
# 49/49 [==============================] - 9s 189ms/step - loss: 15.4847 - mae: 3.2104 - val_loss: 15.7354 - val_mae: 3.2310
# Epoch 6/50
# 49/49 [==============================] - 8s 155ms/step - loss: 15.8056 - mae: 3.2234 - val_loss: 22.5103 - val_mae: 3.5296
# Epoch 7/50
# 49/49 [==============================] - 8s 164ms/step - loss: 14.0557 - mae: 2.9886 - val_loss: 10.2790 - val_mae: 2.5066
# Epoch 8/50
# 49/49 [==============================] - 8s 158ms/step - loss: 8.0375 - mae: 2.1715 - val_loss: 8.1023 - val_mae: 2.2437
# Epoch 9/50
# 49/49 [==============================] - 8s 162ms/step - loss: 5.6204 - mae: 1.8694 - val_loss: 2.7356 - val_mae: 1.2529
# Epoch 10/50
# 49/49 [==============================] - 9s 175ms/step - loss: 1.3524 - mae: 0.8944 - val_loss: 1.8758 - val_mae: 1.1021
# Epoch 11/50
# 49/49 [==============================] - 8s 156ms/step - loss: 0
50
# 49/49 [==============================] - 8s 156ms/step - loss: 0.1498 - mae: 0.3051 - val_loss: 0.1785 - val_mae: 0.3097
# Epoch 36/50
# 49/49 [==============================] - 9s 177ms/step - loss: 0.1843 - mae: 0.3420 - val_loss: 0.3746 - val_mae: 0.4805
# Epoch 37/50
# 49/49 [==============================] - 8s 161ms/step - loss: 0.1921 - mae: 0.3483 - val_loss: 0.1898 - val_mae: 0.3247
# Epoch 38/50
# 49/49 [==============================] - 9s 178ms/step - loss: 0.1278 - mae: 0.2857 - val_loss: 0.5288 - val_mae: 0.6083
# Epoch 39/50
# 49/49 [==============================] - 9s 174ms/step - loss: 0.1711 - mae: 0.3353 - val_loss: 0.2583 - val_mae: 0.3895
# Epoch 40/50
# 49/49 [==============================] - 8s 158ms/step - loss: 0.2254 - mae: 0.3749 - val_loss: 0.3215 - val_mae: 0.4292
# Epoch 41/50
# 49/49 [==============================] - 9s 188ms/step - loss: 0.1253 - mae: 0.2827 - val_loss: 0.1700 - val_mae: 0.3060
# Epoch 42/50
# 49/49 [==============================] - 7s 143ms/step - loss: 0.1516 - mae: 0.3080 - val_loss: 0.2508 - val_mae: 0.3898
# Epoch 43/50
# 49/49 [==============================] - 9s 192ms/step - loss: 0.1889 - mae: 0.3487 - val_loss: 0.2869 - val_mae: 0.4126
# Epoch 44/50
# 49/49 [==============================] - 7s 145ms/step - loss: 0.1419 - mae: 0.2974 - val_loss: 0.2158 - val_mae: 0.3542
# Epoch 45/50
# 49/49 [==============================] - 9s 191ms/step - loss: 0.1328 - mae: 0.2864 - val_loss: 0.2928 - val_mae: 0.4301
# Epoch 46/50
# 49/49 [==============================] - 8s 165ms/step - loss: 0.1207 - mae: 0.2774 - val_loss: 0.2783 - val_mae: 0.4045
# Epoch 47/50
# 49/49 [==============================] - 8s 170ms/step - loss: 0.1405 - mae: 0.2995 - val_loss: 0.2534 - val_mae: 0.3669
# Epoch 48/50
# 49/49 [==============================] - 9s 178ms/step - loss: 0.1229 - mae: 0.2830 - val_loss: 0.2958 - val_mae: 0.4453
# Epoch 49/50
# 49/49 [==============================] - 7s 144ms/step - loss: 0.1025 - mae: 0.2487 - val_loss: 0.2525 - val_mae: 0.3889
# Epoch 50/50
# 49/49 [==============================] - 9s 187ms/step - loss: 0.1608 - mae: 0.3264 - val_loss: 0.2564 - val_mae: 0.3732

# %%
# Save the model
# model_conv1D.save('/content/drive/MyDrive/Colab Notebooks/ML_TCBOB/Scripts/Models/conv1d with callbacks')

# # To load the model later:
# # loaded_model = tf.keras.models.load_model('path_to_save_model')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, lstm_cell_19_layer_call_fn, lstm_cell_19_layer_call_and_return_conditional_losses, lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 5 of 9). These functions will not be directly callable after loading.

# %%
import tensorflow as tf



# Define the MirroredStrategy
strategy = tf.distribute.MirroredStrategy()

def build_conv1D_model():
    n_timesteps = X_train1.shape[1]
    n_features  = X_train1.shape[2]

    with strategy.scope():  # Wrap the model creation in the strategy.scope()
        model = keras.Sequential(name="model_conv1D")
        model.add(keras.layers.Input(shape=(n_timesteps, n_features)))
        model.add(keras.layers.Conv1D(filters=64, kernel_size=24, activation='relu', name="Conv1D_3"))
        model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)))
        model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=False)))
        model.add(keras.layers.Flatten())
        model.add(keras.layers.Dense(32, activation='linear', name="Dense_1"))
        model.add(keras.layers.Dense(2, name="Dense_2"))

        optimizer = tf.keras.optimizers.RMSprop(lr=1e-5, momentum=0.9)

        model.compile(loss="mse", optimizer=optimizer, metrics=['mae'])

    return model

model_conv1D = build_conv1D_model()
model_conv1D.summary()

# Now, train the model without the callbacks
with strategy.scope():
    history = model_conv1D.fit(X_train1, Y_train, epochs=300, batch_size=24, verbose=1, validation_split=0.2)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Model: "model_conv1D"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv1D_3 (Conv1D)           (None, 1420, 64)          1600
#
#  bidirectional_8 (Bidirectio  (None, 1420, 64)         24832
#  nal)
#
#  bidirectional_9 (Bidirectio  (None, 64)               24832
#  nal)
#
#  flatten_4 (Flatten)         (None, 64)                0
#
#  Dense_1 (Dense)             (None, 32)                2080
#
#  Dense_2 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 53,410
# Trainable params: 53,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 49/49 [==============================] - 18s 215ms/step - loss: 674.1940 - mae: 15.6053 - val_loss: 29.2273 - val_mae: 4.8059
# Epoch 2/300
# 49/49 [==============================] - 7s 146ms/step - loss: 15.7138 - mae: 3.2380 - val_loss: 14.7094 - val_mae: 3.2706
# Epoch 3/300
# 49/49 [==============================] - 9s 180ms/step - loss: 14.0910 - mae: 3.0198 - val_loss: 11.2643 - val_mae: 2.6220
# Epoch 4/300
# 49/49 [==============================] - 10s 195ms/step - loss: 12.6910 - mae: 2.8634 - val_loss: 14.6860 - val_mae: 3.0013
# Epoch 5/300
# 49/49 [==============================] - 8s 159ms/step - loss: 10.2726 - mae: 2.5789 - val_loss: 12.0426 - val_mae: 2.9576
# Epoch 6/300
# 49/49 [==============================] - 9s 179ms/step - loss: 6.6065 - mae: 2.0249 - val_loss: 4.7870 - val_mae: 1.6620
# Epoch 7/300
# 49/49 [==============================] - 7s 146ms/step - loss: 1.9714 - mae: 1.0634 - val_loss: 2.5594 - val_mae: 1.2045
# Epoch 8/300
# 49/49 [==============================] - 9s 179ms/step - loss: 1.0097 - mae: 0.7833 - val_loss: 2.0283 - val_mae: 1.0456
# Epoch 9/300
# 49/49 [==============================] - 7s 145ms/step - loss: 0.6387 - mae: 0.6123 - val_loss: 1.2744 - val_mae: 0.8424
# Epoch 10/300
# 49/49 [==============================] - 9s 182ms/step - loss: 0.4954 - mae: 0.5491 - val_loss: 1.4632 - val_mae: 0.9394
# Epoch 11/300
# 49/49 [==============================] - 8s 157ms/step - loss: 0.4484 - mae: 0.5253 - val_loss: 1.0012 - val_mae: 0.7034
# Epoch 12/300
# 49/49 [==============================] - 9s 176ms/step - loss: 0.3642 - mae: 0.4719 - val_loss: 1.1034 - val_mae: 0.7480
# Epoch 13/300
# 49/49 [==============================] - 8s 155ms/step - loss: 0.2592 - mae: 0.3969 - val_loss: 1.6255 - val_mae: 1.0520
# Epoch 14/300
# 49/49 [==============================] - 8s 173ms/step - loss: 0.3699 - mae: 0.4783 - val_loss: 0.6765 - val_mae: 0.5775
# Epoch 15/300
# 49/49 [==============================] - 8s 166ms/step - loss: 0.2879 - mae: 0.4321 - val_loss: 0.5970 - val_mae: 0.5709
# Epoch 16/300
# 49/49 [==============================] - 8s 157ms/step - loss: 0
300
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0450 - mae: 0.1690 - val_loss: 0.1204 - val_mae: 0.2569
# Epoch 297/300
# 49/49 [==============================] - 7s 143ms/step - loss: 0.0495 - mae: 0.1806 - val_loss: 0.1788 - val_mae: 0.3216
# Epoch 298/300
# 49/49 [==============================] - 8s 175ms/step - loss: 0.0518 - mae: 0.1833 - val_loss: 0.1027 - val_mae: 0.2132
# Epoch 299/300
# 49/49 [==============================] - 7s 146ms/step - loss: 0.0583 - mae: 0.1954 - val_loss: 0.1031 - val_mae: 0.2041
# Epoch 300/300
# 49/49 [==============================] - 8s 174ms/step - loss: 0.0545 - mae: 0.1804 - val_loss: 0.1024 - val_mae: 0.2079

# %%
# # Save the model
model_conv1D.save('/content/drive/MyDrive/Colab Notebooks/ML_TCBOB/Scripts/Models/conv1d with mirror')

# # To load the model later:
# # loaded_model = tf.keras.models.load_model('path_to_save_model')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, lstm_cell_25_layer_call_fn, lstm_cell_25_layer_call_and_return_conditional_losses, lstm_cell_26_layer_call_fn, lstm_cell_26_layer_call_and_return_conditional_losses while saving (showing 5 of 9). These functions will not be directly callable after loading.

# %%
import matplotlib.pyplot as plt
print(history.history.keys())

# summarize history for accuracy
#with plt.style.context('ggplot'):
plt.figure(dpi=110)
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('Mean Absolute error')
plt.ylabel('Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()


# summarize history for loss
#with plt.style.context('ggplot'):
plt.figure(dpi=110)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])

# %%
Y_pred = model_conv1D.predict(X_test1)
Y_pred = Y_pred
print(Y_pred[:10])
# Out:
# 12/12 [==============================] - 7s 122ms/step
# [[86.97031    7.3365254]
#  [87.61728    7.536393 ]
#  [87.52728    7.698462 ]
#  [87.19652    8.266476 ]
#  [85.89297    8.154513 ]
#  [85.60713    8.608715 ]
#  [85.23004    9.043444 ]
#  [84.7548     9.032315 ]
#  [84.35639    9.5562725]
#  [83.905716   9.625441 ]]

# %%
lon_test = Y_test[:,0]
lat_test = Y_test[:,1]

lon_pred = Y_pred[:,0]
lat_pred = Y_pred[:,1]

random_dataset = pd.DataFrame()
random_dataset['lon_test'] = lon_test
random_dataset['lat_test'] = lat_test

random_dataset['lon_pred'] = lon_pred
random_dataset['lat_pred'] = lat_pred
random_dataset['deviation'] = np.sqrt(((lon_test-lon_pred)**2)+ ((lat_test-lat_pred)**2))

print("  ")
print("The average error for the deviation is "+ str(random_dataset['deviation'].mean()))
print("  ")

random_dataset
# Out:
#
# The average error for the deviation is 0.4267003379724863
#      lon_test  lat_test   lon_pred   lat_pred  deviation
# 0       87.00      7.00  86.970306   7.336525   0.337833
# 1       87.50      7.25  87.617279   7.536393   0.309476
# 2       87.50      7.50  87.527283   7.698462   0.200329
# 3       87.25      8.25  87.196518   8.266476   0.055962
# 4       85.75      8.25  85.892967   8.154513   0.171922
# ..        ...       ...        ...        ...        ...
# 354     84.25     17.00  84.617577  17.057865   0.372103
# 355     84.50     17.25  84.930603  17.390596   0.452975
# 356     84.50     18.00  84.422165  18.020966   0.080609
# 357     84.50     18.25  84.441803  18.489178   0.246156
# 358     84.50     18.50  84.527061  18.798697   0.299920
#
# [359 rows x 5 columns]

# %%
plt.figure(figsize=(14,4))
plt.plot(lon_test, label='Lon Test')
plt.plot(lon_pred, label='Lon Predition')
plt.xlabel('Value index')
plt.ylabel('Longitude Value')
plt.ylim(80,100)
plt.title("Longitude prediction with ANN")
plt.legend()

plt.figure(figsize=(14,4))
plt.plot(lat_test, label='Lat Test')
plt.plot(lat_pred, label='Lat Predition')
plt.xlabel('Value index')
plt.ylabel('Latitude Value')
plt.ylim(5, 25)
plt.title("Latitude prediction with ANN")
plt.legend()

# %%
X_original_scale = sc.inverse_transform(X_test)
cyclone_number=X_original_scale[:,1]

lon_test = Y_test[:,0]
lat_test = Y_test[:,1]

lon_pred = Y_pred[:,0]
lat_pred = Y_pred[:,1]

random_dataset = pd.DataFrame()
random_dataset['cyclone_number'] = cyclone_number
random_dataset['lon_test'] = lon_test
random_dataset['lat_test'] = lat_test

random_dataset['lon_pred'] = lon_pred
random_dataset['lat_pred'] = lat_pred
random_dataset['deviation'] = np.sqrt(((lon_test-lon_pred)**2)+ ((lat_test-lat_pred)**2))

print("  ")
print("The average error for the deviation is "+ str(random_dataset['deviation'].mean()))
print("  ")

random_dataset
# Out:
#
# The average error for the deviation is 0.4267003379724863
#      cyclone_number  lon_test  lat_test   lon_pred   lat_pred  deviation
# 0              46.0     87.00      7.00  86.970306   7.336525   0.337833
# 1              46.0     87.50      7.25  87.617279   7.536393   0.309476
# 2              46.0     87.50      7.50  87.527283   7.698462   0.200329
# 3              46.0     87.25      8.25  87.196518   8.266476   0.055962
# 4              46.0     85.75      8.25  85.892967   8.154513   0.171922
# ..              ...       ...       ...        ...        ...        ...
# 354            58.0     84.25     17.00  84.617577  17.057865   0.372103
# 355            58.0     84.50     17.25  84.930603  17.390596   0.452975
# 356            58.0     84.50     18.00  84.422165  18.020966   0.080609
# 357            58.0     84.50     18.25  84.441803  18.489178   0.246156
# 358            58.0     84.50     18.50  84.527061  18.798697   0.299920
#
# [359 rows x 6 columns]

# %%
# !apt-get install -qq libgdal-dev libproj-dev
# #!pip install --no-binary shapely shapely
# !pip install --no-binary shapely shapely --force
# !pip install cartopy
# import cartopy.crs as ccrs
# import cartopy.feature as cfeature
# import matplotlib.pyplot as plt

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import cartopy.crs as ccrs

# fig, axs = plt.subplots(3, 4, figsize=(16, 18), dpi=100, subplot_kw={'projection': ccrs.PlateCarree()})

# for i in range(3):
#     for j in range(4):
#         # Taking the cyclone number from input
#         cyclone_number = i * 4 + j + 45

#         # Separating the data for the desired cyclone
#         cyclone_data = random_dataset[random_dataset['cyclone_number'] == float(cyclone_number)]
#         # cyclone_data = cyclone_data.drop(cyclone_data.index[0]) #removing the last row as it creates problem

#         # Plotting the cyclone data
#         axs[i, j].plot(cyclone_data['lon_test'], cyclone_data['lat_test'], '-o', markersize=2.5, transform=ccrs.PlateCarree())
#         axs[i, j].plot(cyclone_data['lon_pred'], cyclone_data['lat_pred'], '-o', markersize=2.5, transform=ccrs.PlateCarree())
#         axs[i, j].set_extent([70, 100, 5, 30], crs=ccrs.PlateCarree())
#         axs[i, j].coastlines(linewidth=1.4)
#         axs[i, j].gridlines(draw_labels=True)
#         axs[i, j].set_title(f"Cyclone {cyclone_number}")
#         # axs[i,j].legend(['Test', 'Prediction'], loc='upper left')

# # Set the overall title for the subplot
# fig.suptitle("6h Prediction no prev feature", fontsize=20, y=1)
# fig.legend(['Test', 'Prediction'], loc='upper left')

# # Adjust spacing between subplots
# fig.tight_layout()

# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

def plot_cyclone_data(cyclone_data_list):
    num_cyclones = len(cyclone_data_list)
    num_rows = (num_cyclones + 3) // 4  # Round up to the nearest multiple of 4
    fig, axs = plt.subplots(num_rows, 4, figsize=(24, 18), dpi=150, subplot_kw={'projection': ccrs.PlateCarree()})
    axs = axs.ravel()

    for i, cyclone_data in enumerate(cyclone_data_list):
        ax = axs[i]
        ax.plot(cyclone_data['lon_test'], cyclone_data['lat_test'], '-o', markersize=2.5, transform=ccrs.PlateCarree())
        ax.plot(cyclone_data['lon_pred'], cyclone_data['lat_pred'], '-o', markersize=2.5, transform=ccrs.PlateCarree())
        ax.set_extent([80, 100, 0, 30], crs=ccrs.PlateCarree())
        ax.coastlines(linewidth=1.4)
        ax.gridlines(draw_labels=True)
        ax.set_title(f"Cyclone {cyclone_data['cyclone_number'].iloc[0]}")
        ax.legend(['Test', 'Prediction'], loc='upper left')

    # Adjust spacing between subplots
    fig.tight_layout()

    plt.show()

# Taking the cyclone numbers from 46 to 58
cyclone_numbers = list(range(46, 58))

# Separating the data for the desired cyclones
cyclone_data_list = [random_dataset[random_dataset['cyclone_number'] == float(cyclone_number)] for cyclone_number in cyclone_numbers]

# Plotting the cyclone data
plot_cyclone_data(cyclone_data_list)

# %%
def plot_cyclone_data(cyclone_data):
    fig = plt.figure(figsize=(20, 12))
    ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
    ax.plot(cyclone_data['lon_test'], cyclone_data['lat_test'], '-o', markersize=5, transform=ccrs.PlateCarree())
    ax.plot(cyclone_data['lon_pred'], cyclone_data['lat_pred'], '-o', markersize=5, transform=ccrs.PlateCarree())
    ax.set_extent([80, 100, 0, 30], crs=ccrs.PlateCarree())
    ax.coastlines(linewidth=1.4)
    ax.gridlines(draw_labels=True)
    plt.legend(['Test', 'Prediction'], loc='upper left')
    plt.show()


# Taking the cyclone number from input
cyclone_number = input("Enter cyclone number: ")

# Separating the data for the desired cyclone
cyclone_data = random_dataset[random_dataset['cyclone_number'] == float(cyclone_number)]

# Plotting the cyclone data

plot_cyclone_data(cyclone_data)
# Out:
# Enter cyclone number: 46

# %% [markdown]
# # Run this cell for same initial point

# %%
# fig, axs = plt.subplots(4, 4, figsize=(16, 18), dpi=100, subplot_kw={'projection': ccrs.PlateCarree()})

# for i in range(4):
#     for j in range(4):
#         # Taking the cyclone number from input
#         cyclone_number = i*4 + j + 53

#         # Separating the data for the desired cyclone
#         cyclone_data = random_dataset[random_dataset['cyclone_number'] == float(cyclone_number)]

#         # Get the first point of lat_test and lon_test
#         first_lat_test = cyclone_data['lat_test'].iloc[0]
#         first_lon_test = cyclone_data['lon_test'].iloc[0]
#         # Create a new DataFrame with the newly added columns
#         plot_df=pd.DataFrame({
#             'lat_pred':[first_lat_test]+cyclone_data['lat_pred'].tolist(),
#             'lon_pred':[first_lon_test]+cyclone_data['lon_pred'].tolist(),
#         })

#         # Plotting the cyclone data
#         axs[i,j].plot(cyclone_data['lon_test'], cyclone_data['lat_test'], '-o', markersize=2.5, transform=ccrs.PlateCarree())
#         axs[i,j].plot(plot_df['lon_pred'], plot_df['lat_pred'], '-o', markersize=2.5, transform=ccrs.PlateCarree())
#         axs[i,j].set_extent([80, 100, 5, 30], crs=ccrs.PlateCarree())
#         axs[i,j].coastlines(linewidth=1.4)
#         axs[i,j].gridlines(draw_labels=True)
#         axs[i,j].set_title(f"Cyclone {cyclone_number}")
# # Set the overall title for the subplot
# fig.suptitle("6h Prediction no prev feature", fontsize=20, y=1)
# fig.legend(['Test', 'Prediction'], loc='upper left')

# # Adjust spacing between subplots
# fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-72-a8ad59db665c> in <cell line: 3>()
#      10
#      11         # Get the first point of lat_test and lon_test
# ---> 12         first_lat_test = cyclone_data['lat_test'].iloc[0]
#      13         first_lon_test = cyclone_data['lon_test'].iloc[0]
#      14         # Create a new DataFrame with the newly added columns
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1623
#    1624             # validate the location
# -> 1625             self._validate_integer(key, axis)
#    1626
#    1627             return self.obj._ixs(key, axis=axis)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1555         len_axis = len(self.obj._get_axis(axis))
#    1556         if key >= len_axis or key < -len_axis:
# -> 1557             raise IndexError("single positional indexer is out-of-bounds")
#    1558
#    1559     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds
